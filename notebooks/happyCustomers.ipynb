# %%
#imports

#data structure
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

#model construction
import seaborn as sns
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree

#model evaluation
import sklearn.metrics as metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


#machine learning
import sklearn.naive_bayes 
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

import pickle

# %%
#uploading data to dataframe
data = pd.read_csv("../data/raw/ACME-HappinessSurvey2020.csv")

# %%
#preliminary data exploration
data.head(5)
# Out:
#    Y  X1  X2  X3  X4  X5  X6
# 0  0   3   3   3   4   2   4
# 1  0   3   2   3   5   4   3
# 2  1   5   3   3   3   3   5
# 3  0   5   4   3   3   3   5
# 4  0   5   4   3   3   3   5

# %%
data.shape
# Out:
# (126, 7)

# %%
data['Y'].value_counts()
# Out:
# Y
# 1    69
# 0    57
# Name: count, dtype: int64

# %%
matrix = data.corr(method="pearson")
print("Correlation Matrix:\n", matrix)
# Out:
# Correlation Matrix:
#             Y        X1        X2        X3        X4        X5        X6
# Y   1.000000  0.280160 -0.024274  0.150838  0.064415  0.224522  0.167669
# X1  0.280160  1.000000  0.059797  0.283358  0.087541  0.432772  0.411873
# X2 -0.024274  0.059797  1.000000  0.184129  0.114838  0.039996 -0.062205
# X3  0.150838  0.283358  0.184129  1.000000  0.302618  0.358397  0.203750
# X4  0.064415  0.087541  0.114838  0.302618  1.000000  0.293115  0.215888
# X5  0.224522  0.432772  0.039996  0.358397  0.293115  1.000000  0.320195
# X6  0.167669  0.411873 -0.062205  0.203750  0.215888  0.320195  1.000000

# %% [markdown]
# * Data has already been cleaned and prepared uniformly. The distribution of unhappy and happy customers is about even. We can continue onto model construction. Before using more advanced machine learning models, I would like to perform a binary logistic regression as results are more directly interpretable.
# * I also see that some features are more correlated to Y than others. I will put a pin in this and compare to how important the features are in logistic regression.

# %% [markdown]
# # Constructing the Model

# %%
y = data["Y"]
X = data[["X1", "X2", "X3", "X4", "X5", "X6"]]
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.15, random_state=42)

reg_model = LogisticRegression(class_weight="balanced").fit(X_train,y_train)

# %%
print(X_test.shape)
print(X_train.shape)
print(y_test.shape)
print(y_train.shape)
# Out:
# (19, 6)
# (107, 6)
# (19,)
# (107,)

# %%
y_pred = reg_model.predict(X_test)

# %%
cm = metrics.confusion_matrix(y_test, y_pred, labels = reg_model.classes_)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm,display_labels=['unhappy', 'happy'])
disp.plot()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.40      0.47        10
#            1       0.50      0.67      0.57         9
#
#     accuracy                           0.53        19
#    macro avg       0.54      0.53      0.52        19
# weighted avg       0.54      0.53      0.52        19

# %% [markdown]
# * Logistic regression has resulted in an accuracy score of .51
# * This model performs as well as random choice... not ideal
# * Next step is to evaluate feature importance to see what features contribute the most predictive value

# %%
coefficients = reg_model.coef_[0]
importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': coefficients,
    'Absolute_Importance': np.abs(coefficients)
})
importance_df
# Out:
#   Feature  Coefficient  Absolute_Importance
# 0      X1     0.637235             0.637235
# 1      X2    -0.186810             0.186810
# 2      X3     0.063388             0.063388
# 3      X4    -0.111432             0.111432
# 4      X5     0.156126             0.156126
# 5      X6     0.173964             0.173964

# %% [markdown]
# The most important features are shown as X1, X2, X5 and X6.

# %% [markdown]
# # Logistic Regression on smaller dataset

# %%
y = data["Y"]
# X = data[["X1", "X2", "X5", "X6"]]
X = data[["X1", "X3", "X5"]] #better results leaving out X2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)
reg_model2 = LogisticRegression(class_weight="balanced").fit(X_train,y_train)
y_pred_reg = reg_model2.predict(X_test)
print(classification_report(y_test, y_pred_reg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71         7
#            1       0.67      0.67      0.67         6
#
#     accuracy                           0.69        13
#    macro avg       0.69      0.69      0.69        13
# weighted avg       0.69      0.69      0.69        13

# %% [markdown]
# * Much better results with less features
# * Next step is to move onto Machine learning models. I have chosen Gaussian since our dataset is small

# %% [markdown]
# # Gaussian NB

# %%
nb = sklearn.naive_bayes.GaussianNB() 
nb.fit(X_train,y_train)
y_pred_gnb = nb.predict(X_test)

# %%
print(classification_report(y_test, y_pred_gnb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62         7
#            1       0.57      0.67      0.62         6
#
#     accuracy                           0.62        13
#    macro avg       0.62      0.62      0.62        13
# weighted avg       0.62      0.62      0.62        13

# %% [markdown]
# Results remain unaccurate

# %% [markdown]
# # Random Forest Classifier

# %%
rf_model = RandomForestClassifier()

param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [3, 5, 7, None],
    "min_samples_leaf": [1, 2, 4],
}
scoring = {
    'accuracy': 'accuracy',
    'precision': 'precision',
    'recall': 'recall',
    'f1': 'f1'
}
#Grid Search
grid_search = GridSearchCV(
    estimator=rf_model, 
    param_grid=param_grid,
    scoring=scoring,
    refit='f1',
    )

# %%
#Fit
grid_search.fit(X_train, y_train)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
grid_search.best_params_
# Out:
# {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 50}

# %%
#Evaluate Model on Test Data
y_pred = grid_search.predict(X_test)
print("Test accuracy on Tuned Model:", accuracy_score(y_test, y_pred))

y_pred = rf_model.predict(X_test)
print("Test accuracy on Untuned Model:", accuracy_score(y_test, y_pred))
# Out:
# Test accuracy on Tuned Model: 0.6923076923076923
# Test accuracy on Untuned Model: 0.6923076923076923

# %% [markdown]
# # Regular Gradient Boosting

# %%
gb = GradientBoostingClassifier(
   
    random_state=42
)

param_grid = {
    "n_estimators": [100, 150, 200],
    "learning_rate": [0.05, 0.1],
    "max_depth": [2, 3],
    "subsample": [0.8, 1.0]
}

# Grid search
grid_search = GridSearchCV(
    estimator=gb,
    param_grid=param_grid,
    scoring=scoring,
    refit='f1',
    n_jobs=-1,
)

# Fit
grid_search.fit(X_train, y_train)
gb.fit(X_train, y_train)
# Evaluate on test set
y_pred = grid_search.predict(X_test)
print("Test accuracy on Tuned Model:", accuracy_score(y_test, y_pred))
y_pred = gb.predict(X_test)
print("Test accuracy on Untuned Model:", accuracy_score(y_test, y_pred))
# Out:
# Test accuracy on Tuned Model: 0.6923076923076923
# Test accuracy on Untuned Model: 0.6923076923076923

# %% [markdown]
# # XGBoost Classifier

# %%
xgb_model = XGBClassifier(objective='binary:logistic', random_state=42, n_jobs=1)
param_grid = {
    "max_depth": [2, 3, 4],
    "min_child_weight": [1, 5, 10],
    "subsample": [0.7, 0.9],
    "colsample_bytree": [0.7, 0.9],
    "learning_rate": [0.01, 0.05, 0.1],
    "n_estimators": [200, 400, 600],
    "reg_alpha": [0, 1],
    "reg_lambda": [1, 10],
    "gamma": [0, 0.1]
}
# Grid search
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    scoring=scoring,
    refit='f1',
    n_jobs=-1, 
)

#Fit
grid_search.fit(X_train, y_train)
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=1, num_parallel_tree=None, ...)

# %%
grid_search.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'gamma': 0,
#  'learning_rate': 0.01,
#  'max_depth': 2,
#  'min_child_weight': 10,
#  'n_estimators': 200,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'subsample': 0.7}

# %%
# Evaluate on test set
y_pred = grid_search.predict(X_test)
print("Test accuracy on Tuned Model:", accuracy_score(y_test, y_pred))

y_pred = xgb_model.predict(X_test)
print("Test accuracy on Untuned Model:", accuracy_score(y_test, y_pred))
# Out:
# Test accuracy on Tuned Model: 0.46153846153846156
# Test accuracy on Untuned Model: 0.6923076923076923

# %% [markdown]
# Oddly, my untuned models are performing better than my tuned models.

# %% [markdown]
# #  K-Nearest Neighbors (KNN)

# %%
#scaling the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
knn_model = KNeighborsClassifier(metric="minkowski") 
knn_model.fit(X_train_scaled, y_train)

param_grid = {
    'n_neighbors': range(1, 31, 2),
    'weights': ['uniform', 'distance'],
    'p': [1, 2]
}

grid_search = GridSearchCV(
    estimator=knn_model, 
    param_grid=param_grid,  
    scoring=scoring,
    refit='f1', 
    n_jobs=-1
)

#fitting the gridsearch
grid_search.fit(X_train_scaled, y_train)
print(grid_search.best_params_)
y_pred_knn = knn_model.predict(X_test_scaled)

y_pred_knn2 = grid_search.best_estimator_.predict(X_test_scaled)

print("Test f1 on Untuned Model:", f1_score(y_test, y_pred_knn))
print("Test f1 on tuned Model:", f1_score(y_test, y_pred_knn2))
# Out:
# {'n_neighbors': 27, 'p': 1, 'weights': 'distance'}
# Test f1 on Untuned Model: 0.7692307692307693
# Test f1 on tuned Model: 0.6666666666666666

# %% [markdown]
# Hyperparameter tuning using 5-fold cross-validation selected k=27, Manhattan distance, and distance weighting. However, the untuned model achieved a higher F1 score on the held-out test set (0.76 vs. 0.66).

# %% [markdown]
# # Support Vector Classifer (SVC)

# %%
svc_model = SVC(random_state=42)
svc_model.fit(X_train_scaled,y_train)
y_pred_svc = svc_model.predict(X_test_scaled)
print("Test f1 on Untuned Model:", f1_score(y_test, y_pred_svc))

param_grid = {
    'C': [0.01, 0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1]
}

grid_search = GridSearchCV(
    estimator=svc_model,
    param_grid=param_grid,
    cv=5,
    scoring=scoring,
    refit='f1',
    n_jobs=-1
)

grid_search.fit(X_train_scaled, y_train)
y_pred_svc2 = grid_search.best_estimator_.predict(X_test_scaled)
print("Test f1 on Tuned Model:", f1_score(y_test, y_pred_svc2))
print("Best params: ", grid_search.best_params_)
# Out:
# Test f1 on Untuned Model: 0.6153846153846154
# Test f1 on Tuned Model: 0.631578947368421
# Best params:  {'C': 0.01, 'gamma': 'scale', 'kernel': 'linear'}

# %% [markdown]
# # Decision Tree Classifier

# %%
#untuned model
dt_model = DecisionTreeClassifier(max_depth=3, random_state=42)
dt_model.fit(X_train, y_train)

y_pred_dt = dt_model.predict(X_test)
print("Test f1 on Tuned Model:", f1_score(y_test, y_pred_dt))

#hyperparameter tuning
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 3, 5, 7, 10],
    'min_samples_split': [5, 7, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(
    estimator=dt_model,
    param_grid=param_grid,
    cv=5,
    scoring=scoring,
    refit='f1',   
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
y_pred_dt2 = grid_search.best_estimator_.predict(X_test)
print("Test f1 on Tuned Model:", f1_score(y_test, y_pred_dt2))
print("Best params: ", grid_search.best_params_)

#plotting decision tree
plt.figure(figsize=(12, 8))
plot_tree(dt_model, filled=True, rounded=True, feature_names=X.columns)
plt.show()
# Out:
# Test f1 on Tuned Model: 0.8
# Test f1 on Tuned Model: 0.8333333333333334
# Best params:  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5}

# %%
#more evaluation metrics 
print(classification_report(y_test, y_pred_dt2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86         7
#            1       0.83      0.83      0.83         6
#
#     accuracy                           0.85        13
#    macro avg       0.85      0.85      0.85        13
# weighted avg       0.85      0.85      0.85        13

# %%
#analysing feature importance again

importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': grid_search.best_estimator_.feature_importances_
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)
importance
# Out:
#   Feature  Importance
# 0      X1    0.453965
# 1      X3    0.305635
# 2      X5    0.240399

# %% [markdown]
# The most important features are:
# 1. 1 - the order was delivered on time
# 2. 3 - they ordered everything they wanted to
# 3. 5 - they are satisfied with the courier

# %%
#analysing if data is overfitted to test data
train_score = grid_search.best_estimator_.score(X_train, y_train)
test_score = grid_search.best_estimator_.score(X_test, y_test)

print(train_score)
print(test_score)
# Out:
# 0.7610619469026548
# 0.8461538461538461

# %% [markdown]
# The score for the training data is actually worse than the test data, meaning that the model performs better on data it has never seen.
#
# The model is not overfitted.

# %%
#saving model
with open('../models/dt_model.pkl', 'wb') as file:
    pickle.dump(grid_search.best_estimator_, file)

#with open('../models/dt_model.pkl', 'rb') as file:
#    my_model = pickle.load(file)

# %% [markdown]
# Among all evaluated models, the tuned Decision Tree achieved the highest F1 score of 0.83 on the test set. The model was selected because it outperformed our machine learning models while remaining hightly interpretable. Feature 1, Feature 3, and Feature 5 were the most influential predictors. The root split indicates that Feature 1 is the primary driver of customer ratings.
